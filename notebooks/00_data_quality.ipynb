# %% [markdown]
# # Data Quality & Cleaning Validation
#
# This notebook validates the cleaned dataset generated by `src/data_loader.py`.
# The goal is to ensure structural consistency before EDA and modeling.

# %%
import pandas as pd

# %%
df = pd.read_parquet("../data/interim/GenerationProdTypeExchange_clean.parquet")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 175344 entries, 0 to 175343
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   time_utc                175344 non-null  datetime64[us, UTC]
#  1   time_dk                 175344 non-null  datetime64[us]
#  2   price_area              175344 non-null  str
#  3   version                 175344 non-null  str
#  4   gross_con               175344 non-null  float64
#  5   offshore_wind_power     175344 non-null  float64
#  6   onshore_wind_power      175344 non-null  float64
#  7   hydro_power             175344 non-null  float64
#  8   solar_power             175344 non-null  float64
#  9   solar_power_self_con    175344 non-null  float64
#  10  biomass                 175344 non-null  float64
#  11  biogas                  175344 non-null  float64
#  12  waste                   175344 non-null  float64
# ...

# %%
df.head()
# Out:
#                    time_utc             time_dk price_area version  \
# 0 2014-12-31 23:00:00+00:00 2015-01-01 00:00:00        DK1   Final
# 1 2015-01-01 00:00:00+00:00 2015-01-01 01:00:00        DK1   Final
# 2 2015-01-01 01:00:00+00:00 2015-01-01 02:00:00        DK1   Final
# 3 2015-01-01 02:00:00+00:00 2015-01-01 03:00:00        DK1   Final
# 4 2015-01-01 03:00:00+00:00 2015-01-01 04:00:00        DK1   Final
#
#      gross_con  offshore_wind_power  onshore_wind_power  hydro_power  \
# 0  1838.981873           675.776130         1195.760240     1.733855
# 1  1776.395668           628.515209         1202.969711     1.718058
# 2  1697.858998           566.793276         1199.164012     1.720085
# 3  1624.951160           549.766937         1334.949746     1.718178
# 4  1592.044638           659.884966         1472.919800     1.724078
#
#    solar_power  solar_power_self_con  ...  fossil_gas  fossil_oil  \
# 0     7.768254                   0.0  ...  149.453258    6.189905
# ...

# %%
df.isna().mean().sort_values(ascending=False).head(10)
# Out:
# exchange_great_britain    0.902941
# exchange_netherlands      0.704327
# exchange_norway           0.500000
# time_utc                  0.000000
# waste                     0.000000
# exchange_sweden           0.000000
# exchange_germany          0.000000
# exchange_great_belt       0.000000
# fossil_hard_coal          0.000000
# fossil_oil                0.000000
# dtype: float64

# %% [markdown]
# Observation:
# - Exchange columns have structural missing values (likely due to area-specific connections).
# - Core production variables contain no missing values.

# %%
df.duplicated(["price_area","time_utc"]).sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Conclusion
#
# The dataset is structurally clean and ready for exploratory analysis and feature engineering.
# No critical missing values were detected in core production variables.
